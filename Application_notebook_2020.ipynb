# %%
#Importing the necessary modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Reading the data about gini indexes from Frederick Solt database
df = pd.read_csv(r'swiid8_2.csv')

# %%
#Visualizing the first 5 rows
df.head()
# Out:
#    Unnamed: 0      country    year  gini_disp  _1_gini_disp  _2_gini_disp  \
# 0           0  Afghanistan  2007.0        NaN      0.315654      0.298476
# 1           1  Afghanistan  2008.0        NaN      0.311721      0.300269
# 2           2  Afghanistan  2009.0        NaN      0.334216      0.294252
# 3           3  Afghanistan  2010.0        NaN      0.327413      0.294283
# 4           4  Afghanistan  2011.0        NaN      0.313301      0.282497
#
#    _3_gini_disp  _4_gini_disp  _5_gini_disp  _6_gini_disp  ...  _92_rel_red  \
# 0      0.320578      0.306987      0.352508      0.318673  ...          NaN
# 1      0.322511      0.314552      0.351009      0.315231  ...          NaN
# 2      0.306747      0.314404      0.359352      0.305574  ...          NaN
# 3      0.313016      0.315273      0.341562      0.303612  ...          NaN
# 4      0.311004      0.313787      0.350486      0.302729  ...          NaN
#
# ...

# %%
#Visualizing the last 20 rows
df.tail(20)
# Out:
#      Unnamed: 0  country    year  gini_disp  _1_gini_disp  _2_gini_disp  \
# 470         470    Benin  2012.0        NaN      0.448907      0.432085
# 471         471    Benin  2013.0        NaN      0.450310      0.442485
# 472         472    Benin  2014.0        NaN      0.457061      0.445266
# 473         473    Benin  2015.0        NaN      0.464504      0.456335
# 474         474   Bhutan  2003.0        NaN      0.387213      0.406520
# 475         475   Bhutan  2004.0        NaN      0.390139      0.403188
# 476         476   Bhutan  2005.0        NaN      0.402465      0.383955
# 477         477   Bhutan  2006.0        NaN      0.393952      0.375603
# 478         478   Bhutan  2007.0        NaN      0.394829      0.367573
# 479         479   Bhutan  2008.0        NaN      0.408920      0.381642
# 480         480   Bhutan  2009.0        NaN      0.421610      0.392375
# 481         481   Bhutan  2010.0        NaN      0.414271      0.391799
# ...

# %%
#Understanding the shape of the data
df.shape
# Out:
# (490, 408)

# %%
#Understanding data types
df.dtypes
# Out:
# Unnamed: 0        int64
# country          object
# year            float64
# gini_disp       float64
# _1_gini_disp    float64
#                  ...
# _97_rel_red     float64
# _98_rel_red     float64
# _99_rel_red     float64
# _100_rel_red    float64
# _mi_miss          int64
# Length: 408, dtype: object

# %%
#Viewing column names
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'country', 'year', 'gini_disp', '_1_gini_disp',
#        '_2_gini_disp', '_3_gini_disp', '_4_gini_disp', '_5_gini_disp',
#        '_6_gini_disp',
#        ...
#        '_92_rel_red', '_93_rel_red', '_94_rel_red', '_95_rel_red',
#        '_96_rel_red', '_97_rel_red', '_98_rel_red', '_99_rel_red',
#        '_100_rel_red', '_mi_miss'],
#       dtype='object', length=408)

# %%
#Understanding missing values
df.isnull().sum()
# Out:
# Unnamed: 0        0
# country           0
# year              0
# gini_disp       490
# _1_gini_disp      0
#                ...
# _97_rel_red     315
# _98_rel_red     315
# _99_rel_red     315
# _100_rel_red    315
# _mi_miss          0
# Length: 408, dtype: int64

# %%
#Counting entries for each country
df['country'].value_counts()
# Out:
# Argentina              57
# Bangladesh             53
# Australia              50
# Belgium                39
# Austria                35
# Barbados               32
# Belarus                30
# Armenia                30
# Algeria                24
# Azerbaijan             21
# Albania                17
# Belize                 17
# Andorra                16
# Bhutan                 15
# Benin                  14
# Bahamas                13
# Angola                 10
# Anguilla                8
# Afghanistan             6
# Bahrain                 1
# Bolivia                 1
# Antigua and Barbuda     1
# Name: country, dtype: int64

# %%
#Reading data about gini indexes from World Bank
df1 = pd.read_csv(r'world_gini.csv')

# %%
#Viewing the first 5 rows
df1.head()
# Out:
#   Country Name Country Code                    Indicator Name Indicator Code  \
# 0        Aruba          ABW  GINI index (World Bank estimate)    SI.POV.GINI
# 1  Afghanistan          AFG  GINI index (World Bank estimate)    SI.POV.GINI
# 2       Angola          AGO  GINI index (World Bank estimate)    SI.POV.GINI
# 3      Albania          ALB  GINI index (World Bank estimate)    SI.POV.GINI
# 4      Andorra          AND  GINI index (World Bank estimate)    SI.POV.GINI
#
#    1960  1961  1962  1963  1964  1965  ...  2010  2011  2012  2013  2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  29.0   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#    2015  2016  2017  2018  2019
# ...

# %%
#Viewing the Shape of the data
df1.shape
# Out:
# (264, 64)

# %%
#Understanding total null values in the dataset
df1.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              264
#                  ...
# 2015              189
# 2016              225
# 2017              239
# 2018              264
# 2019              264
# Length: 64, dtype: int64

# %%
#Viewing Country Names
df1['Country Name'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria',
# ...

# %%
#Reading data about GDP of countries from World Bank
df2 = pd.read_csv(r'world_gdp.csv')

# %%
#Viewing the first 5 rows
df2.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
#Understanding the data types
df2.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Length: 64, dtype: object

# %%
#Viewing the first 20 rows
df2.head(20)
# Out:
#             Country Name Country Code     Indicator Name  Indicator Code  \
# 0                  Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1            Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2                 Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3                Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4                Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# 5             Arab World          ARB  GDP (current US$)  NY.GDP.MKTP.CD
# 6   United Arab Emirates          ARE  GDP (current US$)  NY.GDP.MKTP.CD
# 7              Argentina          ARG  GDP (current US$)  NY.GDP.MKTP.CD
# 8                Armenia          ARM  GDP (current US$)  NY.GDP.MKTP.CD
# 9         American Samoa          ASM  GDP (current US$)  NY.GDP.MKTP.CD
# 10   Antigua and Barbuda          ATG  GDP (current US$)  NY.GDP.MKTP.CD
# 11             Australia          AUS  GDP (current US$)  NY.GDP.MKTP.CD
# ...

# %%
#Understanding null values
df2.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              132
#                  ...
# 2015               13
# 2016               14
# 2017               17
# 2018               25
# 2019              264
# Length: 64, dtype: int64

# %%
#Understanding the shape of the data
df2.shape
# Out:
# (264, 64)

# %%
#Reading data about GDP growth from World Bank
df3 = pd.read_csv(r'world_gdp_growth.csv')

# %%
#Viewing first 5 rows
df3.head()
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965  ...       2010      2011       2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  -3.685030  3.446055  -1.369863
# 1   NaN   NaN   NaN   NaN   NaN  ...  14.362441  0.426355  12.752287
# 2   NaN   NaN   NaN   NaN   NaN  ...   4.859220  3.471981   8.542147
# 3   NaN   NaN   NaN   NaN   NaN  ...   3.706891  2.545323   1.417524
# 4   NaN   NaN   NaN   NaN   NaN  ...  -5.358826 -4.646543  -1.615218
#
#        2013      2014      2015      2016      2017      2018  2019
# ...

# %%
#Understanding the shape of the data
df3.shape
# Out:
# (264, 64)

# %%
#Understanding null values
df3.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              264
#                  ...
# 2015               14
# 2016               15
# 2017               15
# 2018               24
# 2019              264
# Length: 64, dtype: int64

# %%
#Selecting data about Benin for country specific analysis
df5 = df4.loc[df4['country'] == 'Benin']

# %%
#Viewing the dataframe
df5
# Out:
#      Unnamed: 0 country  year  _1_gini_disp  _2_gini_disp  _3_gini_disp  \
# 460         460   Benin  2002      0.410435      0.458490      0.412629
# 461         461   Benin  2003      0.407747      0.466103      0.424197
# 462         462   Benin  2004      0.420942      0.457270      0.431086
# 463         463   Benin  2005      0.431012      0.460674      0.435882
# 464         464   Benin  2006      0.430517      0.461621      0.430612
# 465         465   Benin  2007      0.434368      0.464867      0.438889
# 466         466   Benin  2008      0.439543      0.459603      0.439967
# 467         467   Benin  2009      0.446866      0.448859      0.452350
# 468         468   Benin  2010      0.448655      0.436204      0.447152
# 469         469   Benin  2011      0.446895      0.429135      0.444364
# 470         470   Benin  2012      0.448907      0.432085      0.441306
# 471         471   Benin  2013      0.450310      0.442485      0.456685
# ...

# %%
#Plotting the changes in the Gini Index
df5.plot(x ='year', y='_1_gini_disp', kind = 'line', title = 'Benin Gini Index from 2002-2014')
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.show()
# Out:
# C:\Users\Chiundidza\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:575: UserWarning: The handle <matplotlib.lines.Line2D object at 0x0000021D89D65448> has a label of '_1_gini_disp' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
#Selecting relevant GDP data for period 2002-2014 for comparison with Gini Index
dfp = df2[['2002','2003', '2004', '2005', '2006','2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]

# %%
#Viewing first 5 rows
dfp.head()
# Out:
#            2002          2003          2004          2005          2006  \
# 0  1.941341e+09  2.021229e+09  2.228492e+09  2.330726e+09  2.424581e+09
# 1  4.055177e+09  4.515563e+09  5.226775e+09  6.209140e+09  6.971287e+09
# 2  1.528559e+10  1.781271e+10  2.355205e+10  3.697092e+10  5.238101e+10
# 3  4.348070e+09  5.611492e+09  7.184681e+09  8.052076e+09  8.896074e+09
# 4  1.733117e+09  2.398646e+09  2.935659e+09  3.255789e+09  3.543257e+09
#
#            2007          2008          2009          2010          2011  \
# 0  2.615084e+09  2.745251e+09  2.498883e+09  2.390503e+09  2.549721e+09
# 1  9.747886e+09  1.010922e+10  1.243909e+10  1.585657e+10  1.780428e+10
# 2  6.526645e+10  8.853861e+10  7.030716e+10  8.379950e+10  1.117900e+11
# 3  1.067732e+10  1.288135e+10  1.204422e+10  1.192696e+10  1.289087e+10
# 4  4.016972e+09  4.007353e+09  3.660531e+09  3.355695e+09  3.442063e+09
#
#            2012          2013          2014
# 0  2.534637e+09  2.581564e+09  2.649721e+09
# ...

# %%
#Plotting the changes in Annual GDP for Benin
row = dfp.iloc[16]
row.plot(kind='line', title = 'Benin Annual GDP from 2002-2014')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()
